# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
dt1 = pd.read_csv("./data/[1h]BTCUSDT.csv")

# %%
dt1
# Out:
#                Start           Stop      Open     Close       Low      High  \
# 0      1502942400000  1502945999999   4261.48   4308.83   4261.32   4313.62
# 1      1502946000000  1502949599999   4308.83   4315.32   4291.37   4328.69
# 2      1502949600000  1502953199999   4330.29   4324.35   4309.37   4345.45
# 3      1502953200000  1502956799999   4316.62   4349.99   4287.41   4349.99
# 4      1502956800000  1502960399999   4333.32   4360.69   4333.32   4377.85
# ...              ...            ...       ...       ...       ...       ...
# 29471  1609444800000  1609448399999  28897.84  29126.70  28862.00  29139.65
# 29472  1609448400000  1609451999999  29126.71  28966.36  28900.79  29169.55
# 29473  1609452000000  1609455599999  28966.36  29100.84  28910.19  29143.73
# 29474  1609455600000  1609459199999  29100.83  28923.63  28780.00  29110.35
# 29475  1609459200000  1609462799999  28923.63  28995.13  28690.17  29031.34
#
#             Volume
# 0        47.181009
# ...

# %%
plt.plot(dt1['Start'], dt1['Open'], color='green')

# %%
plt.plot(dt1['Stop'], dt1['Close'], color='purple')

# %%
plt.figure(figsize=(15,10))
plt.plot(dt1['Start'], dt1['Open'], color='red')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(dt1['Start'], dt1['Open'], color='blue')
plt.show()

# %%
plt.plot(dt1['Start'], dt1['Low'], color='yellow')

# %%
plt.plot(dt1['Start'], dt1['High'], color='orange')

# %%
plt.figure(figsize=(15,5))
plt.plot(dt1['Start'], dt1['Volume'], color='#b0bf1a')

# %%
plt.figure(figsize=(15,5))
plt.plot(dt1['Start'],dt1['Volume'], color='magenta')

# %%
plt.hist(dt1['Volume'], color='lime')
# Out:
# (array([2.7635e+04, 1.5080e+03, 2.3100e+02, 5.8000e+01, 2.6000e+01,
#         1.1000e+01, 4.0000e+00, 0.0000e+00, 2.0000e+00, 1.0000e+00]),
#  array([    0.       ,  4725.5762685,  9451.152537 , 14176.7288055,
#         18902.305074 , 23627.8813425, 28353.457611 , 33079.0338795,
#         37804.610148 , 42530.1864165, 47255.762685 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dt1['Volume'],bins=70)
# Out:
# (array([5.879e+03, 8.808e+03, 6.100e+03, 3.325e+03, 1.728e+03, 1.089e+03,
#         7.060e+02, 4.430e+02, 3.370e+02, 2.240e+02, 1.960e+02, 1.350e+02,
#         1.080e+02, 6.500e+01, 5.400e+01, 4.900e+01, 3.300e+01, 2.800e+01,
#         2.900e+01, 1.600e+01, 2.200e+01, 8.000e+00, 1.300e+01, 1.500e+01,
#         7.000e+00, 5.000e+00, 8.000e+00, 2.000e+00, 5.000e+00, 4.000e+00,
#         3.000e+00, 6.000e+00, 1.000e+00, 4.000e+00, 3.000e+00, 5.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 3.000e+00, 1.000e+00, 1.000e+00,
#         2.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([    0.        ,   675.08232407,  1350.16464814,  2025.24697221,
# ...

# %%
dt2 = pd.read_csv("./data/[1m]BTCUSDT.csv")

# %%
dt2
# Out:
#                  Start           Stop      Open     Close       Low      High  \
# 0        1502942400000  1502942459999   4261.48   4261.48   4261.48   4261.48
# 1        1502942460000  1502942519999   4261.48   4261.48   4261.48   4261.48
# 2        1502942520000  1502942579999   4280.56   4280.56   4280.56   4280.56
# 3        1502942580000  1502942639999   4261.48   4261.48   4261.48   4261.48
# 4        1502942640000  1502942699999   4261.48   4261.48   4261.48   4261.48
# ...                ...            ...       ...       ...       ...       ...
# 1767788  1609458960000  1609459019999  28978.91  28975.06  28969.99  28988.06
# 1767789  1609459020000  1609459079999  28975.06  28975.03  28955.35  28981.41
# 1767790  1609459080000  1609459139999  28975.03  28923.67  28923.15  28977.10
# 1767791  1609459140000  1609459199999  28923.66  28923.63  28903.86  28952.28
# 1767792  1609459200000  1609459259999  28923.63  28961.66  28913.12  28961.66
#
#             Volume
# ...

# %%
plt.figure(figsize=(15,5))
plt.plot(dt2['Start'], dt2['Open'], color='brown')

# %%
plt.figure(figsize=(15,5))
plt.plot(dt2['Stop'], dt2['Close'], color='black')

# %%
plt.figure(figsize=(20,5))
plt.plot(dt2['Start'], dt2['Low'], color='#b600d9')

# %%
plt.figure(figsize=(20,5))
plt.plot(dt2['Start'], dt2['High'])

# %%
plt.figure(figsize=(20,5))
plt.plot(dt2['Start'], dt2['Volume'])

# %%
plt.hist(dt2['Volume'], color='pink')
# Out:
# (array([1.760036e+06, 6.241000e+03, 1.095000e+03, 2.810000e+02,
#         9.200000e+01, 3.300000e+01, 9.000000e+00, 4.000000e+00,
#         1.000000e+00, 1.000000e+00]),
#  array([   0.       ,  356.4139435,  712.827887 , 1069.2418305,
#         1425.655774 , 1782.0697175, 2138.483661 , 2494.8976045,
#         2851.311548 , 3207.7254915, 3564.139435 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(dt2, x="Volume", color='#dfc6a7')
# Out:
# <AxesSubplot:xlabel='Volume', ylabel='Count'>
